# %%
# https://www.mdpi.com/2076-3417/12/19/10077

# %%
import os
# !pwd

from pathlib import Path

dir_path = Path(r"/Users/rabinatwayana/Rabina/CDE II/Wildfire Project/SAR-Burnt-Area-Mapping/")

if dir_path.exists():
    os.chdir(dir_path)
else:
    print("Directory does not exist! Please check the path.")

from pathlib import Path
folder_path = Path("MachineLearning/output/model/")
folder_path.mkdir(parents=True, exist_ok=True)

folder_path = Path("MachineLearning/output/feature_importance/")
folder_path.mkdir(parents=True, exist_ok=True)

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
from utils import run_model, create_fish_net
import config
from sklearn.ensemble import RandomForestClassifier

TILE_SIZE=config.TILE_SIZE
from datetime import datetime

# %%
metrics_combined=[]
train_duration={}
hyperparameter_tuning=True
gt_image_path="MachineLearning/input/ground_truth/02_gt/gt_palisade.tif"
rgb_image_path="MachineLearning/input/S2/rgbn_clip.tif"

# %%
## Random Forest
# train_ids = [135,88,172,361,63,79,300,211,315,257,202,176,180,209,155,96,121,72,48,137,192,304,358,374,381,103,105,159,162,214,216,246,271,273,302,268,295,266,292,290,233,319,324,231,329,327,263,312,415]
# test_ids = [146,129,123,344,378,248,132,189,242,297,321,235,356]

## XGBoost
train_ids = [135,88,172,361,63,79,211,315,257,176,180,155,96,121,72,137,192,358,381,103,159,162,216,246,271,302,268,295,266,290,233,319,324,231,329,327,263,415,273]
test_ids = [146,129,123,344,378,248,132,189,242,297,321,235,356]
# val_ids = [312,202,209,105,214,300,374,304,292,48] ## hard coded in run_model


tiles=create_fish_net("MachineLearning/input/sar/02_clip/S1A_asc_32611_avg_clip.tif", rgb_image_path, tile_size=TILE_SIZE,plot_fig=True,train_ids=train_ids,test_ids=test_ids)
# Out:
# 113
# Fishnet tile generation done

# %%
scheme_1 =  True
scheme_2 = True
scheme_3 = True
scheme_4 = True

scheme_5 = True
scheme_6 = True
scheme_7 = True
scheme_8 = True

# %% [markdown]
# ## Model best hyper parameter selection

# %%
tune_train_ids = [146,129,123,344,378,248,132,189,242,297,321,235,356,274,231,290,49,409,193,287,208]

## XGBoost
# random_search_model = XGBClassifier(random_state=42)
# params = {
#     'n_estimators': [50, 100, 150],  # Number of boosting rounds (trees)
#     'max_depth': [10, 20, 30],  # Maximum depth of trees
#     'learning_rate': [0.01, 0.05, 0.1],  # Step size shrinking to prevent overfitting
#     'min_child_weight': [1, 5, 10],  # Minimum sum of instance weight (hessian) in a child
#     'subsample': [0.3, 0.5, 0.7],  # Fraction of samples used for each tree
#     'colsample_bytree': [0.3, 0.5, 0.7],  # Fraction of features to consider for each tree
#     'colsample_bylevel': [0.3, 0.5, 0.7],  # Fraction of features to consider for each level
#     'gamma': [0, 1, 5],  # Minimum loss reduction required to make a further partition
#     'scale_pos_weight': [1, 10, 20],  # Adjusts for imbalanced classes
#     'reg_alpha': [0, 0.1, 1],  # L1 regularization term on weights (similar to Lasso)
#     'reg_lambda': [1, 10, 100],  # L2 regularization term on weights (similar to Ridge)
#     'objective': ['binary:logistic'],  # Specify binary classification objective
#     'booster': ['gbtree', 'dart', 'gblinear'],  # Types of boosters: gbtree, dart, or gblinear
#     'eval_metric': ['logloss', 'error'],  # Evaluation metrics
#     'scale_pos_weight': [1, 10, 50],  # Scaling factor for imbalanced classes
#     'max_delta_step': [0, 1, 10],  # Maximum delta step for tree growing
#     'tree_method': ['auto', 'exact', 'approx', 'hist', 'gpu_hist'],  # Tree construction algorithm
# }

## Random forest
# random_search_model = RandomForestClassifier(random_state=42)
# params = {
#         'n_estimators': [50, 100, 150],  # Number of trees
#         'max_depth': [10, 20,30],  # Depth of trees
#         'min_samples_split': [10, 20, 40],  # Minimum samples to split
#         'max_features': [2, 4, 'sqrt', 'log2'],  # Features to consider at each split
#         'class_weight': ['balanced_subsample', 'balanced'],  # Handle class imbalance
#         'max_samples': [0.3,0.5, 0.7],
#         "bootstrap":[True,False]  # Fraction of samples to train each tree on
#     }

##run following to get best hyperparameter
# print("scheme_1********************")
# feature_image_path=f"MachineLearning/output/feature_image/palisades_sar_avg_asc.tif"
# get_best_hyperparameter(random_search_model,feature_image_path,gt_image_path,params,tune_train_ids,TILE_SIZE)

# print("scheme_2**********************")
# feature_image_path=f"MachineLearning/output/feature_image/palisades_sar_avg_desc.tif"
# get_best_hyperparameter(random_search_model,feature_image_path,gt_image_path,params,tune_train_ids,TILE_SIZE)

# print("scheme_3***********************")
# feature_image_path=f"MachineLearning/output/feature_image/palisades_sar_avg_asc_desc.tif"
# get_best_hyperparameter(random_search_model,feature_image_path,gt_image_path,params,tune_train_ids,TILE_SIZE)

# print("scheme_4************************")
# feature_image_path=f"MachineLearning/output/feature_image/palisades_sar_avg_asc_desc_glcm.tif"
# get_best_hyperparameter(random_search_model,feature_image_path,gt_image_path,params,tune_train_ids,TILE_SIZE)

# %% [markdown]
# ## Random Forest Model

# %%
## Final hypertuned RF Model
# model_name="RandomForest"
# RF_Model=RandomForestClassifier(
#     n_estimators= 150, 
#     class_weight="balanced_subsample",
#     max_samples= 0.7, 
#     min_samples_split= 10, 
#     max_features= 4,
#     max_depth=15,
#     bootstrap=True)
# model=RF_Model
# best_param={}

# %% [markdown]
# ## XGBoost Model

# %%
# # chatgpt used one
xgboost_best_param = {
    'booster': 'dart',
    'tree_method': 'hist',
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',  
    'learning_rate': 0.03,         
    'n_estimators': 800,            
    'early_stopping_rounds': 10,   
    'max_depth': 15,                
    'min_child_weight': 5,         
    'gamma': 2,                    
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'colsample_bylevel': 0.7,
    'reg_lambda': 5,                
    'reg_alpha': 2,                 
    'max_delta_step': 1,
    'drop_rate': 0.1,      
    'skip_drop': 0.5, 
}


XGBClassifier_Model=XGBClassifier(**xgboost_best_param)

model=XGBClassifier_Model
model_name="XGB"
best_param=xgboost_best_param

# %%
output_model_dir="MachineLearning/output/model/"
output_feat_imp_dir="MachineLearning/output/feature_importance/"
feature_column_names=["RBD_VV", "RBD_VH", "RBR_VV", "RBR_VH","ΔRVI"]
feature_column_names_with_glcm=["RBD_VV", "RBD_VH", "RBR_VV", "RBR_VH","ΔRVI",'p1','p2','p3']
glcm_feature_column_names=['p1','p2','p3']

# %%
if scheme_1:
    print("******* scheme 1 *********")
    start_timestamp = datetime.now()
    
    file_name="palisades_sar_single_asc"
    metrics_1=run_model(
            feature_image_path=f"MachineLearning/output/feature_image/{file_name}.tif", 
                gt_image_path=gt_image_path,
                feature_column_names=feature_column_names, 
                model_name=model_name,
                model=model, #scheme_3_model,
                model_param=best_param,
                output_model_dir=output_model_dir,
                output_feat_imp_dir=output_feat_imp_dir,
                extended_file_name=f"_{file_name}",
                train_ids=train_ids, 
                test_ids=test_ids, 
                tile_size=TILE_SIZE
               )
    metrics_combined.append(metrics_1)
    end_timestamp=datetime.now()
    total_time=end_timestamp-start_timestamp
    train_duration['scheme_1']=total_time

if scheme_2:
    print("******* scheme 2 *********")
    start_timestamp = datetime.now()
    #1 Asc glcm
    file_name="palisades_sar_single_desc"
    metrics_2=run_model(feature_image_path=f"MachineLearning/output/feature_image/{file_name}.tif", 
              gt_image_path=gt_image_path,
              feature_column_names=feature_column_names, 
              model_name=model_name,
              model=model, #scheme_3_model,
              model_param=best_param,
              output_model_dir=output_model_dir,
               output_feat_imp_dir=output_feat_imp_dir,
               extended_file_name=f"_{file_name}",
               train_ids=train_ids, 
               test_ids=test_ids, 
               tile_size=TILE_SIZE
               )
    metrics_combined.append(metrics_2)
    end_timestamp=datetime.now()
    total_time=end_timestamp-start_timestamp
    train_duration['scheme_2']=total_time

if scheme_3:
    print("******* scheme 3 *********")
    start_timestamp = datetime.now()

    #1 Asc avg
    file_name="palisades_sar_single_asc_desc"
    metrics_3=run_model(feature_image_path=f"MachineLearning/output/feature_image/{file_name}.tif", 
              gt_image_path=gt_image_path,
              feature_column_names=feature_column_names, 
              model_name=model_name,
              model=model, #scheme_3_model,
              model_param=best_param,
              output_model_dir=output_model_dir,
               output_feat_imp_dir=output_feat_imp_dir,
               extended_file_name=f"_{file_name}",
               train_ids=train_ids, 
               test_ids=test_ids, 
               tile_size=TILE_SIZE
               )
    metrics_combined.append(metrics_3)
    end_timestamp=datetime.now()
    total_time=end_timestamp-start_timestamp
    train_duration['scheme_3']=total_time

if scheme_4:
    print("******* scheme 4 *********")
    start_timestamp = datetime.now()

    #1 Asc avg + glcm
    file_name="palisades_sar_single_asc_desc_glcm"
    metrics_4=run_model(feature_image_path=f"MachineLearning/output/feature_image/{file_name}.tif", 
              gt_image_path=gt_image_path,
              feature_column_names=feature_column_names_with_glcm, 
              model_name=model_name,
              model=model, #scheme_3_model,
              model_param=best_param,
              output_model_dir=output_model_dir,
               output_feat_imp_dir=output_feat_imp_dir,
               extended_file_name=f"_{file_name}",
               train_ids=train_ids, 
               test_ids=test_ids, 
               tile_size=TILE_SIZE
               )
    metrics_combined.append(metrics_4)
    end_timestamp=datetime.now()
    total_time=end_timestamp-start_timestamp
    train_duration['scheme_4']=total_time

if scheme_5:
    print("******* scheme 5 *********")
    start_timestamp = datetime.now()

    file_name="palisades_sar_avg_asc"
    metrics_5=run_model(
            feature_image_path=f"MachineLearning/output/feature_image/{file_name}.tif", 
              gt_image_path=gt_image_path,
              feature_column_names=feature_column_names, 
            model_name=model_name,
              model=model, #scheme_3_model,
              model_param=best_param,
              output_model_dir=output_model_dir,
               output_feat_imp_dir=output_feat_imp_dir,
               extended_file_name=f"_{file_name}",
               train_ids=train_ids, 
               test_ids=test_ids, 
               tile_size=TILE_SIZE
               )
    metrics_combined.append(metrics_5)
    end_timestamp=datetime.now()
    total_time=end_timestamp-start_timestamp
    train_duration['scheme_5']=total_time

if scheme_6:
    print("******* scheme 6 *********")
    start_timestamp = datetime.now()
    
    #1 Asc glcm
    file_name="palisades_sar_avg_desc"
    metrics_6=run_model(feature_image_path=f"MachineLearning/output/feature_image/{file_name}.tif", 
              gt_image_path=gt_image_path,
              feature_column_names=feature_column_names, 
              model_name=model_name,
              model=model, #scheme_3_model,
              model_param=best_param,
              output_model_dir=output_model_dir,
               output_feat_imp_dir=output_feat_imp_dir,
               extended_file_name=f"_{file_name}",
               train_ids=train_ids, 
               test_ids=test_ids, 
               tile_size=TILE_SIZE
               )
    metrics_combined.append(metrics_6)
    end_timestamp=datetime.now()
    total_time=end_timestamp-start_timestamp
    train_duration['scheme_6']=total_time

if scheme_7:
    print("******* scheme 7 *********")
    start_timestamp = datetime.now()

    #1 Asc avg
    file_name="palisades_sar_avg_asc_desc"
    metrics_7=run_model(feature_image_path=f"MachineLearning/output/feature_image/{file_name}.tif", 
              gt_image_path=gt_image_path,
              feature_column_names=feature_column_names, 
              model_name=model_name,
              model=model, #scheme_3_model,
              model_param=best_param,
              output_model_dir=output_model_dir,
               output_feat_imp_dir=output_feat_imp_dir,
               extended_file_name=f"_{file_name}",
               train_ids=train_ids, 
               test_ids=test_ids, 
               tile_size=TILE_SIZE
               )
    metrics_combined.append(metrics_7)
    end_timestamp=datetime.now()
    total_time=end_timestamp-start_timestamp
    train_duration['scheme_7']=total_time

    
if scheme_8:
    print("******* scheme 8 *********")
    start_timestamp = datetime.now()
    #1 Asc avg + glcm
    file_name="palisades_sar_avg_asc_desc_glcm"
    metrics_8=run_model(feature_image_path=f"MachineLearning/output/feature_image/{file_name}.tif", 
              gt_image_path=gt_image_path,
              feature_column_names=feature_column_names_with_glcm, 
              model_name=model_name,
              model=model, #scheme_3_model,
              model_param=best_param,
              output_model_dir=output_model_dir,
               output_feat_imp_dir=output_feat_imp_dir,
               extended_file_name=f"_{file_name}",
               train_ids=train_ids, 
               test_ids=test_ids, 
               tile_size=TILE_SIZE
               )
    metrics_combined.append(metrics_8)
    end_timestamp=datetime.now()
    total_time=end_timestamp-start_timestamp
    train_duration['scheme_8']=total_time
# Out:
# ******* scheme 1 *********
# ***************XGB*********************
# Fishnet tile generation done
# [0]	validation_0-logloss:0.68572
# [1]	validation_0-logloss:0.67873
# [2]	validation_0-logloss:0.67145
# [3]	validation_0-logloss:0.66351
# [4]	validation_0-logloss:0.65495
# [5]	validation_0-logloss:0.64706
# [6]	validation_0-logloss:0.64060
# [7]	validation_0-logloss:0.63368
# [8]	validation_0-logloss:0.62673
# [9]	validation_0-logloss:0.62081
# [10]	validation_0-logloss:0.61354
# [11]	validation_0-logloss:0.60736
# [12]	validation_0-logloss:0.60263
# [13]	validation_0-logloss:0.59593
# [14]	validation_0-logloss:0.58988
# [15]	validation_0-logloss:0.58364
# [16]	validation_0-logloss:0.57893
# [17]	validation_0-logloss:0.57411
# [18]	validation_0-logloss:0.56972
# [19]	validation_0-logloss:0.56421
# [20]	validation_0-logloss:0.56050
# [21]	validation_0-logloss:0.55619
# [22]	validation_0-logloss:0.55178
# [23]	validation_0-logloss:0.54780
# [24]	validation_0-logloss:0.54345
# [25]	validation_0-logloss:0.54066
# [26]	validation_0-logloss:0.53700
# [27]	validation_0-logloss:0.53445
# [28]	validation_0-logloss:0.53022
# [29]	validation_0-logloss:0.52767
# [30]	validation_0-logloss:0.52382
# [31]	validation_0-logloss:0.52152
# [32]	validation_0-logloss:0.51937
# [33]	validation_0-logloss:0.51652
# [34]	validation_0-logloss:0.51429
# [35]	validation_0-logloss:0.51201
# [36]	validation_0-logloss:0.51010
# [37]	validation_0-logloss:0.50746
# [38]	validation_0-logloss:0.50557
# [39]	validation_0-logloss:0.50305
# [40]	validation_0-logloss:0.50074
# [41]	validation_0-logloss:0.49894
# [42]	validation_0-logloss:0.49690
# [43]	validation_0-logloss:0.49539
# [44]	validation_0-logloss:0.49292
# [45]	validation_0-logloss:0.49178
# [46]	validation_0-logloss:0.48962
# [47]	validation_0-logloss:0.48822
# [48]	validation_0-logloss:0.48675
# [49]	validation_0-logloss:0.48583
# [50]	validation_0-logloss:0.48493
# [51]	validation_0-logloss:0.48379
# [52]	validation_0-logloss:0.48241
# [53]	validation_0-logloss:0.48038
# [54]	validation_0-logloss:0.47927
# [55]	validation_0-logloss:0.47822
# [56]	validation_0-logloss:0.47758
# [57]	validation_0-logloss:0.47597
# [58]	validation_0-logloss:0.47458
# [59]	validation_0-logloss:0.47333
# [60]	validation_0-logloss:0.47248
# [61]	validation_0-logloss:0.47197
# [62]	validation_0-logloss:0.47144
# [63]	validation_0-logloss:0.47122
# [64]	validation_0-logloss:0.47053
# [65]	validation_0-logloss:0.46948
# [66]	validation_0-logloss:0.46935
# [67]	validation_0-logloss:0.46852
# [68]	validation_0-logloss:0.46819
# [69]	validation_0-logloss:0.46718
# [70]	validation_0-logloss:0.46583
# [71]	validation_0-logloss:0.46556
# [72]	validation_0-logloss:0.46528
# [73]	validation_0-logloss:0.46467
# [74]	validation_0-logloss:0.46454
# [75]	validation_0-logloss:0.46447
# [76]	validation_0-logloss:0.46458
# [77]	validation_0-logloss:0.46446
# [78]	validation_0-logloss:0.46438
# [79]	validation_0-logloss:0.46353
# [80]	validation_0-logloss:0.46337
# [81]	validation_0-logloss:0.46302
# [82]	validation_0-logloss:0.46272
# [83]	validation_0-logloss:0.46266
# [84]	validation_0-logloss:0.46245
# [85]	validation_0-logloss:0.46194
# [86]	validation_0-logloss:0.46120
# [87]	validation_0-logloss:0.46116
# [88]	validation_0-logloss:0.46107
# [89]	validation_0-logloss:0.46103
# [90]	validation_0-logloss:0.46111
# [91]	validation_0-logloss:0.46008
# [92]	validation_0-logloss:0.45956
# [93]	validation_0-logloss:0.45860
# [94]	validation_0-logloss:0.45807
# [95]	validation_0-logloss:0.45801
# [96]	validation_0-logloss:0.45725
# [97]	validation_0-logloss:0.45633
# [98]	validation_0-logloss:0.45594
# [99]	validation_0-logloss:0.45607
# [100]	validation_0-logloss:0.45600
# [101]	validation_0-logloss:0.45615
# [102]	validation_0-logloss:0.45642
# [103]	validation_0-logloss:0.45677
# [104]	validation_0-logloss:0.45620
# [105]	validation_0-logloss:0.45522
# [106]	validation_0-logloss:0.45529
# [107]	validation_0-logloss:0.45590
# [108]	validation_0-logloss:0.45487
# [109]	validation_0-logloss:0.45472
# [110]	validation_0-logloss:0.45469
# [111]	validation_0-logloss:0.45455
# [112]	validation_0-logloss:0.45455
# [113]	validation_0-logloss:0.45356
# [114]	validation_0-logloss:0.45360
# [115]	validation_0-logloss:0.45362
# [116]	validation_0-logloss:0.45306
# [117]	validation_0-logloss:0.45226
# [118]	validation_0-logloss:0.45210
# [119]	validation_0-logloss:0.45194
# [120]	validation_0-logloss:0.45181
# [121]	validation_0-logloss:0.45177
# [122]	validation_0-logloss:0.45134
# [123]	validation_0-logloss:0.45135
# [124]	validation_0-logloss:0.45136
# [125]	validation_0-logloss:0.45137
# [126]	validation_0-logloss:0.45112
# [127]	validation_0-logloss:0.45079
# [128]	validation_0-logloss:0.45003
# [129]	validation_0-logloss:0.45024
# [130]	validation_0-logloss:0.45023
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 6
#       3 start_timestamp = datetime.now()
#       5 file_name="palisades_sar_single_asc"
# ----> 6 metrics_1=run_model(
#       7         feature_image_path=f"MachineLearning/output/feature_image/{file_name}.tif",
#       8             gt_image_path=gt_image_path,
#       9             feature_column_names=feature_column_names,
#      10             model_name=model_name,
#      11             model=model, #scheme_3_model,
#      12             model_param=best_param,
#      13             output_model_dir=output_model_dir,
#      14             output_feat_imp_dir=output_feat_imp_dir,
#      15             extended_file_name=f"_{file_name}",
#      16             train_ids=train_ids,
#      17             test_ids=test_ids,
#      18             tile_size=TILE_SIZE
#      19            )
#      20 metrics_combined.append(metrics_1)
#      21 end_timestamp=datetime.now()
#
# File ~/Rabina/CDE II/Wildfire Project/SAR-Burnt-Area-Mapping/utils.py:629, in run_model(feature_image_path, gt_image_path, feature_column_names, model_name, model, model_param, output_model_dir, output_feat_imp_dir, extended_file_name, train_ids, test_ids, tile_size)
#     626     # Create model
#     627     model = XGBClassifier(**model_param)
# --> 629     model.fit(
#     630         X_train, y_train,
#     631         eval_set=[(X_val, y_val)],
#     632         # early_stopping_rounds=10,
#     633         # verbose=True
#     634     )
#     635 else:
#     637     model.fit(X_train, y_train)
#
# File ~/miniforge3/envs/wildfire_burnt_env/lib/python3.12/site-packages/xgboost/core.py:705, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     703 for k, arg in zip(sig.parameters, args):
#     704     kwargs[k] = arg
# --> 705 return func(**kwargs)
#
# File ~/miniforge3/envs/wildfire_burnt_env/lib/python3.12/site-packages/xgboost/sklearn.py:1682, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1660 model, metric, params, feature_weights = self._configure_fit(
#    1661     xgb_model, params, feature_weights
#    1662 )
#    1663 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1664     missing=self.missing,
#    1665     X=X,
#    (...)   1679     feature_types=self.feature_types,
#    1680 )
# -> 1682 self._Booster = train(
#    1683     params,
#    1684     train_dmatrix,
#    1685     self.get_num_boosting_rounds(),
#    1686     evals=evals,
#    1687     early_stopping_rounds=self.early_stopping_rounds,
#    1688     evals_result=evals_result,
#    1689     obj=obj,
#    1690     custom_metric=metric,
#    1691     verbose_eval=verbose,
#    1692     xgb_model=model,
#    1693     callbacks=self.callbacks,
#    1694 )
#    1696 if not callable(self.objective):
#    1697     self.objective = params["objective"]
#
# File ~/miniforge3/envs/wildfire_burnt_env/lib/python3.12/site-packages/xgboost/core.py:705, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     703 for k, arg in zip(sig.parameters, args):
#     704     kwargs[k] = arg
# --> 705 return func(**kwargs)
#
# File ~/miniforge3/envs/wildfire_burnt_env/lib/python3.12/site-packages/xgboost/training.py:183, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     181 if cb_container.before_iteration(bst, i, dtrain, evals):
#     182     break
# --> 183 bst.update(dtrain, iteration=i, fobj=obj)
#     184 if cb_container.after_iteration(bst, i, dtrain, evals):
#     185     break
#
# File ~/miniforge3/envs/wildfire_burnt_env/lib/python3.12/site-packages/xgboost/core.py:2223, in Booster.update(self, dtrain, iteration, fobj)
#    2219 self._assign_dmatrix_features(dtrain)
#    2221 if fobj is None:
#    2222     _check_call(
# -> 2223         _LIB.XGBoosterUpdateOneIter(
#    2224             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2225         )
#    2226     )
#    2227 else:
#    2228     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
print(metrics_combined)
# Convert to DataFrame
df_metrics = pd.DataFrame(metrics_combined)

# Save to CSV
df_metrics.to_csv(f'MachineLearning/output/{model_name}_evaluation_metrics_test.csv', index=False)

print("CSV file created successfully!")

# %%
train_duration
